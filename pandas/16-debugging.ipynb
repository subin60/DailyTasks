# %% [markdown]
# # Debugging Python code
#
# Go through the exercises below.
#
# - Each exercise contains some code with **one or more mistakes** on it.
# - The mistakes can either prompt an error or not.
# - There might be multiple ways to fix the mistakes.
# - Improving the code readibility is also encourage.

# %%
# data creation
beatles = ["John Lennon", "Paul McCartney", "George Harrison", "Ringo Star"]

numbers = [1, 2, 3, 4, 5]

capitals = {"Germany": "Berlin", 
            "Russia": "Moscow",
            "France": "Paris",
            "China": "Beijing",
            "Egypt": "Cairo",
            "Brazil": "Sao Paulo"
            }

top_profitable_films = {
    "Film": ["Avengers: Endgame", "Avatar", "Titanic", "Star Wars: The Force Awakens", "Jurassic World",
             "The Lion King", "The Avengers", "Frozen II", "Frozen", "Beauty and the Beast"],
    "Year": ["2019", "2007", "1997", "2015", "2015", "2019", "2012", "2019", "2013", "2017"],
    "Worldwide Gross (in billions)": ["2.798", "2.789", "2.194", "2.073", "1.673", "1.656", "1.519", 
                                      "1.450", "1.276", "1.263"]
    }

# %% [markdown]
# ## Exercise 1:

# %%
for c in Capitals.keys():
  print(f"{c} is the capital of {Capitals[c]}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-eab7ba37ea75> in <module>
# ----> 1 for c in Capitals.keys():
#       2   print(f"{c} is the capital of {Capitals[c]}")
#
# NameError: name 'Capitals' is not defined

# %%
# step 1 - C to c
for c in capitals.keys():
  print(f"{c} is the capital of {capitals[c]}")
# Out:
# Germany is the capital of Berlin
# Russia is the capital of Moscow
# France is the capital of Paris
# China is the capital of Beijing
# Egypt is the capital of Cairo
# Brazil is the capital of Sao Paulo

# %%
# step 2
for c in capitals.keys():
  print(f"{capitals[c]} is the capital of {c}")
# Out:
# Berlin is the capital of Germany
# Moscow is the capital of Russia
# Paris is the capital of France
# Beijing is the capital of China
# Cairo is the capital of Egypt
# Sao Paulo is the capital of Brazil

# %%
# step 3 - better variables
for country in capitals.keys():
  print(f"{capitals[country]} is the capital of {country}")
# Out:
# Berlin is the capital of Germany
# Moscow is the capital of Russia
# Paris is the capital of France
# Beijing is the capital of China
# Cairo is the capital of Egypt
# Sao Paulo is the capital of Brazil

# %% [markdown]
# ## Exercise 2:
# Let's imagine we want to show our love for Ringo Star and print a love statement for him as many times as numbers are in the `numbers` list. For all Beatles who are not Ringo, we want to print as many times a hate statement. The output should look like this:
#
# ```
# I hate John Lennon!
# I hate Paul McCartney!
# I hate George Harrison!
# I love Ringo Star!
#
#
# I hate John Lennon!
# I hate Paul McCartney!
# I hate George Harrison!
# I love Ringo Star!
#
#
# I hate John Lennon!
# I hate Paul McCartney!
# I hate George Harrison!
# I love Ringo Star!
#
#
# I hate John Lennon!
# I hate Paul McCartney!
# I hate George Harrison!
# I love Ringo Star!
#
#
# I hate John Lennon!
# I hate Paul McCartney!
# I hate George Harrison!
# I love Ringo Star!
# ```

# %%
for beatle in beatles:
  if beatle = "Ringo Star":
    for n in numbers:
      print(f"I love {beatle}!")
  if beatle != "Ringo Star":
    print(f"I hate {beatle}!")
      print("\n")
# Out:
#   File "<ipython-input-7-379944ed508e>", line 2
#     if beatle = "Ringo Star":
#               ^
# SyntaxError: invalid syntax

# %%
for n in numbers:
  for beatle in beatles:
    if beatle == "Ringo Star":
      print(f"I love {beatle}!")
    if beatle != "Ringo Star":
      print(f"I hate {beatle}!")
  print("\n")
# Out:
# I hate John Lennon!
# I hate Paul McCartney!
# I hate George Harrison!
# I love Ringo Star!
#
#
# I hate John Lennon!
# I hate Paul McCartney!
# I hate George Harrison!
# I love Ringo Star!
#
#
# I hate John Lennon!
# I hate Paul McCartney!
# I hate George Harrison!
# I love Ringo Star!
#
#
# I hate John Lennon!
# I hate Paul McCartney!
# I hate George Harrison!
# I love Ringo Star!
#
#
# I hate John Lennon!
# I hate Paul McCartney!
# I hate George Harrison!
# I love Ringo Star!

# %%
for n in numbers:
  for beatle in beatles:
    if beatle == "Ringo Star":
      print(f"I love {beatle}!")
    else:
      print(f"I hate {beatle}!")
  print("\n")
# Out:
# I hate John Lennon!
# I hate Paul McCartney!
# I hate George Harrison!
# I love Ringo Star!
#
#
# I hate John Lennon!
# I hate Paul McCartney!
# I hate George Harrison!
# I love Ringo Star!
#
#
# I hate John Lennon!
# I hate Paul McCartney!
# I hate George Harrison!
# I love Ringo Star!
#
#
# I hate John Lennon!
# I hate Paul McCartney!
# I hate George Harrison!
# I love Ringo Star!
#
#
# I hate John Lennon!
# I hate Paul McCartney!
# I hate George Harrison!
# I love Ringo Star!

# %% [markdown]
# ## Exercise 3:

# %%
top_profitable_films = pd.DataFrame(top_profitable_films)
top_profitable_films.head
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-1172a015e85c> in <module>
# ----> 1 top_profitable_films = pd.DataFrame(top_profitable_films)
#       2 top_profitable_films.head
#
# NameError: name 'pd' is not defined

# %%
top_profitable_films.columns
# Out:
# Index(['Film', 'Year', 'Worldwide Gross (in billions)'], dtype='object')

# %%
import pandas as pd
top_profitable_films = pd.DataFrame(top_profitable_films)
top_profitable_films.head()
# Out:
#                            Film  Year Worldwide Gross (in billions)
# 0             Avengers: Endgame  2019                         2.798
# 1                        Avatar  2007                         2.789
# 2                       Titanic  1997                         2.194
# 3  Star Wars: The Force Awakens  2015                         2.073
# 4                Jurassic World  2015                         1.673

# %% [markdown]
# ## Exercise 4:

# %%
top_films_df[top_films_df["Film"]=="Avatar"]["Year"] = "2009"
# Out:
# <ipython-input-44-a69360be8c6c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top_films_df[top_films_df["Film"]=="Avatar"]["Year"] = 2009

# %%
top_profitable_films.loc[top_profitable_films["Film"]=="Avatar","Year"] = '2009'

# %% [markdown]
# ## Exercise 5:
#
# We want to get the average gross profit of all films:

# %%
top_films_df["Worldwide Gross (in billions)"].avg()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-54-6fe72320270d> in <module>
# ----> 1 top_films_df["Worldwide Gross (in billions)"].avg()
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'avg'

# %%
top_profitable_films["Worldwide Gross (in billions)"].astype(float).mean().round(1)
# Out:
# 1.9

# %%
top_profitable_films["Worldwide Gross (in billions)"] = pd.to_numeric(top_profitable_films["Worldwide Gross (in billions)"])

# %%
top_profitable_films["Worldwide Gross (in billions)"].mean()
# Out:
# 1.8691000000000002
